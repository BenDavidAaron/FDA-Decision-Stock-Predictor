# %% [markdown]
# # ...So
# We now have a SQLite db with a bunch of stock price data

# %%
# %load_ext sql
# %sql sqlite:///training_data.db
# Out:
# /opt/conda/lib/python2.7/site-packages/IPython/config.py:13: ShimWarning: The `IPython.config` package has been deprecated since IPython 4.0. You should import from traitlets.config instead.
#   "You should import from traitlets.config instead.", ShimWarning)
# /opt/conda/lib/python2.7/site-packages/IPython/utils/traitlets.py:5: UserWarning: IPython.utils.traitlets has moved to a top-level traitlets package.
#   warn("IPython.utils.traitlets has moved to a top-level traitlets package.")
# u'Connected: None@training_data.db'

# %%
# %%sql
# SELECT * FROM sqlite_master WHERE "type"='table';
# Out:
# Done.
# [(u'table', u'ENTA', u'ENTA', 4, u'CREATE TABLE "ENTA" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'AGN', u'AGN', 28, u'CREATE TABLE "AGN" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'LIFE', u'LIFE', 114, u'CREATE TABLE "LIFE" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'KITE', u'KITE', 199, u'CREATE TABLE "KITE" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'BSTC', u'BSTC', 217, u'CREATE TABLE "BSTC" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'AAAP', u'AAAP', 300, u'CREATE TABLE "AAAP" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
# ...

# %%
# %%sql
# select *, [index]
# FROM NEW
# LIMIT 1000
# Out:
# Done.
# [(u'2000-01-04', 3500.0, 5.9, 5.9, 4.7, 4.7, u'2000-01-04'),
#  (u'2000-01-05', 500.0, 7.5, 7.5, 7.5, 7.5, u'2000-01-05'),
#  (u'2000-01-06', 7800.0, 6.9, 7.0, 6.3, 5.3, u'2000-01-06'),
#  (u'2000-01-07', 0.0, 5.1, 6.9, 6.9, 5.1, u'2000-01-07'),
#  (u'2000-01-10', 0.0, 5.1, 6.7, 6.7, 5.1, u'2000-01-10'),
#  (u'2000-01-11', 0.0, 5.1, 6.7, 6.7, 5.1, u'2000-01-11'),
#  (u'2000-01-12', 0.0, 5.1, 5.1, 5.1, 5.1, u'2000-01-12'),
#  (u'2000-01-13', 0.0, 5.1, 6.7, 6.7, 5.1, u'2000-01-13'),
#  (u'2000-01-14', 0.0, 5.1, 6.7, 6.7, 5.1, u'2000-01-14'),
#  (u'2000-01-18', 0.0, 5.1, 6.7, 6.7, 5.0, u'2000-01-18'),
#  (u'2000-01-19', 1500.0, 5.0, 5.0, 5.0, 5.0, u'2000-01-19'),
#  (u'2000-01-20', 0.0, 4.1, 6.5, 6.5, 4.1, u'2000-01-20'),
#  (u'2000-01-21', 0.0, 4.1, 6.5, 6.5, 4.1, u'2000-01-21'),
#  (u'2000-01-24', 0.0, 3.7, 6.5, 6.5, 3.7, u'2000-01-24'),
#  (u'2000-01-25', 200.0, 6.4, 6.5, 6.5, 6.4, u'2000-01-25'),
#  (u'2000-01-26', 0.0, 4.8, 6.2, 6.2, 4.8, u'2000-01-26'),
# ...

# %%
# %%sql
# select volume, close
# FROM NEW
# join(select )
# Out:
# Done.
# [(3500.0, 5.9),
#  (500.0, 7.5),
#  (7800.0, 6.9),
#  (0.0, 5.1),
#  (0.0, 5.1),
#  (0.0, 5.1),
#  (0.0, 5.1),
#  (0.0, 5.1),
#  (0.0, 5.1),
#  (0.0, 5.1),
#  (1500.0, 5.0),
#  (0.0, 4.1),
#  (0.0, 4.1),
#  (0.0, 3.7),
#  (200.0, 6.4),
#  (0.0, 4.8),
#  (0.0, 4.8),
#  (0.0, 4.8),
#  (0.0, 4.8),
#  (0.0, 4.6),
#  (0.0, 4.6),
#  (0.0, 4.6),
#  (200.0, 4.6),
#  (0.0, 3.9),
#  (0.0, 3.8),
#  (0.0, 3.5),
#  (0.0, 3.7),
#  (0.0, 3.7),
#  (0.0, 3.8),
#  (0.0, 3.7),
#  (0.0, 3.5),
#  (0.0, 3.5),
#  (0.0, 3.5),
#  (0.0, 3.5),
#  (0.0, 3.5),
#  (0.0, 3.5),
#  (0.0, 3.5),
#  (0.0, 3.5),
#  (0.0, 3.5),
#  (0.0, 3.5),
#  (0.0, 3.5),
#  (0.0, 3.5),
#  (0.0, 3.5),
#  (0.0, 3.5),
#  (0.0, 3.5),
#  (0.0, 3.3),
#  (0.0, 3.3),
#  (0.0, 3.3),
#  (0.0, 3.3),
#  (0.0, 3.3),
#  (0.0, 3.3),
#  (0.0, 3.4),
#  (0.0, 3.3),
#  (0.0, 3.3),
#  (0.0, 3.3),
#  (0.0, 3.3),
#  (0.0, 3.3),
#  (0.0, 3.3),
#  (0.0, 3.3),
#  (0.0, 3.3),
#  (0.0, 3.3),
#  (0.0, 3.3),
#  (0.0, 3.3),
#  (0.0, 3.3),
#  (0.0, 3.5),
# ...

# %%
# %%sql
# SELECT close, volume, date, ticker

# %%
import sqlite3
conn = sqlite3.connect('training_data.db')
c = conn.cursor()

# %%
table_name = 'NEW'   # name of the table to be queried
id_column = 'DATE'
some_id = 123456
column_2 = 'CLOSE'
column_3 = 'EVENT'

# %%
c.execute('''
SELECT index, CLOSE, VOLUME  
FROM new 
JOIN historical_pdufas 
ON new.[index] = historical_pdufas.date
WHERE historical_pdufas.ticker LIKE "new"
'''.\
        format(tn=table_name))

# %%
c.fetchall()
# Out:
# [(u'2006-10-06',
#   0.0,
#   11.6,
#   12.8,
#   12.8,
#   11.6,
#   0,
#   u'pdufa',
#   u'NEW',
#   u'2006-10-06',
#   11.6,
#   0.0)]
