# %% [markdown]
# # ...So
# We now have a SQLite db with a bunch of stock price data

# %%
# %load_ext sql
# %sql sqlite:///training_data.db
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# u'Connected: None@training_data.db'

# %%
# %%sql
# SELECT * FROM sqlite_master WHERE "type"='table';
# Out:
# Done.
# [(u'table', u'historical_pdufas', u'historical_pdufas', 2, u'CREATE TABLE historical_pdufas (\n\t"index" BIGINT, \n\t"Ticker" TEXT, \n\t"DateTime" DATETIME\n)'),
#  (u'table', u'ENTA', u'ENTA', 4, u'CREATE TABLE "ENTA" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'AGN', u'AGN', 28, u'CREATE TABLE "AGN" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'LIFE', u'LIFE', 114, u'CREATE TABLE "LIFE" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'KITE', u'KITE', 199, u'CREATE TABLE "KITE" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'BSTC', u'BSTC', 217, u'CREATE TABLE "BSTC" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'AAAP', u'AAAP', 300, u'CREATE TABLE "AAAP" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'FLML', u'FLML', 312, u'CREATE TABLE "FLML" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'SAGE', u'SAGE', 320, u'CREATE TABLE "SAGE" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'PAR', u'PAR', 338, u'CREATE TABLE "PAR" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'BPTH', u'BPTH', 423, u'CREATE TABLE "BPTH" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'AGEN', u'AGEN', 471, u'CREATE TABLE "AGEN" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'ESPR', u'ESPR', 557, u'CREATE TABLE "ESPR" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'RETA', u'RETA', 579, u'CREATE TABLE "RETA" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'IRWD', u'IRWD', 588, u'CREATE TABLE "IRWD" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'VNDA', u'VNDA', 627, u'CREATE TABLE "VNDA" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'RPTP', u'RPTP', 684, u'CREATE TABLE "RPTP" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'BYSI', u'BYSI', 734, u'CREATE TABLE "BYSI" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'ACUR', u'ACUR', 738, u'CREATE TABLE "ACUR" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'DEPO', u'DEPO', 826, u'CREATE TABLE "DEPO" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'ARIA', u'ARIA', 912, u'CREATE TABLE "ARIA" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'CNAT', u'CNAT', 920, u'CREATE TABLE "CNAT" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'ALDR', u'ALDR', 942, u'CREATE TABLE "ALDR" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'VRTX', u'VRTX', 960, u'CREATE TABLE "VRTX" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'THRX', u'THRX', 1046, u'CREATE TABLE "THRX" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'HPTX', u'HPTX', 1102, u'CREATE TABLE "HPTX" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'AGLE', u'AGLE', 1118, u'CREATE TABLE "AGLE" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'DRRX', u'DRRX', 1128, u'CREATE TABLE "DRRX" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'EXEL', u'EXEL', 1211, u'CREATE TABLE "EXEL" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'FLXN', u'FLXN', 1296, u'CREATE TABLE "FLXN" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'XBIT', u'XBIT', 1316, u'CREATE TABLE "XBIT" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'JNCE', u'JNCE', 1330, u'CREATE TABLE "JNCE" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'MEIP', u'MEIP', 1335, u'CREATE TABLE "MEIP" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'ADMP', u'ADMP', 1402, u'CREATE TABLE "ADMP" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'ADMS', u'ADMS', 1487, u'CREATE TABLE "ADMS" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'OTIC', u'OTIC', 1506, u'CREATE TABLE "OTIC" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'ACOR', u'ACOR', 1523, u'CREATE TABLE "ACOR" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'CEMP', u'CEMP', 1582, u'CREATE TABLE "CEMP" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'KMPH', u'KMPH', 1611, u'CREATE TABLE "KMPH" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'RLYP', u'RLYP', 1625, u'CREATE TABLE "RLYP" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'ANAB', u'ANAB', 1630, u'CREATE TABLE "ANAB" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'TNXP', u'TNXP', 1635, u'CREATE TABLE "TNXP" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'ITEK', u'ITEK', 1663, u'CREATE TABLE "ITEK" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'JNJ', u'JNJ', 1678, u'CREATE TABLE "JNJ" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'PSTI', u'PSTI', 1765, u'CREATE TABLE "PSTI" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'SNY', u'SNY', 1835, u'CREATE TABLE "SNY" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'AMAG', u'AMAG', 1910, u'CREATE TABLE "AMAG" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'AFMD', u'AFMD', 1995, u'CREATE TABLE "AFMD" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'GWPH', u'GWPH', 2012, u'CREATE TABLE "GWPH" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'GBT', u'GBT', 2036, u'CREATE TABLE "GBT" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'CRTX', u'CRTX', 2049, u'CREATE TABLE "CRTX" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'CRMD', u'CRMD', 2096, u'CREATE TABLE "CRMD" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'LPCN', u'LPCN', 2133, u'CREATE TABLE "LPCN" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'SVRA', u'SVRA', 2154, u'CREATE TABLE "SVRA" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'VCEL', u'VCEL', 2165, u'CREATE TABLE "VCEL" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'PTGX', u'PTGX', 2252, u'CREATE TABLE "PTGX" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'ADXS', u'ADXS', 2261, u'CREATE TABLE "ADXS" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'PHMMF', u'PHMMF', 2321, u'CREATE TABLE "PHMMF" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'DCTH', u'DCTH', 2323, u'CREATE TABLE "DCTH" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'AEGR', u'AEGR', 2398, u'CREATE TABLE "AEGR" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'TBPH', u'TBPH', 2430, u'CREATE TABLE "TBPH" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'DVAX', u'DVAX', 2448, u'CREATE TABLE "DVAX" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'SGEN', u'SGEN', 2515, u'CREATE TABLE "SGEN" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'IOVA', u'IOVA', 2596, u'CREATE TABLE "IOVA" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'BHVN', u'BHVN', 2631, u'CREATE TABLE "BHVN" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'NVLS', u'NVLS', 2635, u'CREATE TABLE "NVLS" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'EGRX', u'EGRX', 2648, u'CREATE TABLE "EGRX" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'QCOR', u'QCOR', 2668, u'CREATE TABLE "QCOR" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'AFFY', u'AFFY', 2739, u'CREATE TABLE "AFFY" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'BCRX', u'BCRX', 2793, u'CREATE TABLE "BCRX" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'AXSM', u'AXSM', 2879, u'CREATE TABLE "AXSM" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'GLMD', u'GLMD', 2891, u'CREATE TABLE "GLMD" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'CPRX', u'CPRX', 2911, u'CREATE TABLE "CPRX" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'DBVT', u'DBVT', 2966, u'CREATE TABLE "DBVT" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'RDUS', u'RDUS', 2983, u'CREATE TABLE "RDUS" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'IPXL', u'IPXL', 3001, u'CREATE TABLE "IPXL" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'NGSX', u'NGSX', 3086, u'CREATE TABLE "NGSX" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'RMTI', u'RMTI', 3088, u'CREATE TABLE "RMTI" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'NVS', u'NVS', 3174, u'CREATE TABLE "NVS" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'RNN', u'RNN', 3260, u'CREATE TABLE "RNN" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'ALTH', u'ALTH', 3319, u'CREATE TABLE "ALTH" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'ALDX', u'ALDX', 3381, u'CREATE TABLE "ALDX" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'OPHT', u'OPHT', 3399, u'CREATE TABLE "OPHT" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'KURA', u'KURA', 3420, u'CREATE TABLE "KURA" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'CBIO', u'CBIO', 3432, u'CREATE TABLE "CBIO" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'NVO', u'NVO', 3445, u'CREATE TABLE "NVO" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'MELA', u'MELA', 3531, u'CREATE TABLE "MELA" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'OPK', u'OPK', 3582, u'CREATE TABLE "OPK" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'EBIO', u'EBIO', 3668, u'CREATE TABLE "EBIO" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'HRTX', u'HRTX', 3688, u'CREATE TABLE "HRTX" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'ONTX', u'ONTX', 3774, u'CREATE TABLE "ONTX" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'MRUS', u'MRUS', 3796, u'CREATE TABLE "MRUS" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'SPPI', u'SPPI', 3805, u'CREATE TABLE "SPPI" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'AMGN', u'AMGN', 3891, u'CREATE TABLE "AMGN" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'CRBP', u'CRBP', 3977, u'CREATE TABLE "CRBP" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'DOR', u'DOR', 3993, u'CREATE TABLE "DOR" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'WCRX', u'WCRX', 4071, u'CREATE TABLE "WCRX" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'KTOV', u'KTOV', 4107, u'CREATE TABLE "KTOV" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'SMMT', u'SMMT', 4119, u'CREATE TABLE "SMMT" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'AZN', u'AZN', 4133, u'CREATE TABLE "AZN" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'VRX', u'VRX', 4219, u'CREATE TABLE "VRX" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'CADX', u'CADX', 4305, u'CREATE TABLE "CADX" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'EPIX', u'EPIX', 4342, u'CREATE TABLE "EPIX" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'IGXT', u'IGXT', 4355, u'CREATE TABLE "IGXT" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'HALO', u'HALO', 4409, u'CREATE TABLE "HALO" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'MBVX', u'MBVX', 4476, u'CREATE TABLE "MBVX" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'BLRX', u'BLRX', 4494, u'CREATE TABLE "BLRX" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'OREX', u'OREX', 4527, u'CREATE TABLE "OREX" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'OPTR', u'OPTR', 4579, u'CREATE TABLE "OPTR" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'LOXO', u'LOXO', 4614, u'CREATE TABLE "LOXO" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'SNDX', u'SNDX', 4632, u'CREATE TABLE "SNDX" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'CNCE', u'CNCE', 4642, u'CREATE TABLE "CNCE" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'IMGN', u'IMGN', 4662, u'CREATE TABLE "IMGN" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'LJPC', u'LJPC', 4748, u'CREATE TABLE "LJPC" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'MNOV', u'MNOV', 4777, u'CREATE TABLE "MNOV" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'GALE', u'GALE', 4830, u'CREATE TABLE "GALE" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'ATRS', u'ATRS', 4878, u'CREATE TABLE "ATRS" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'CLSD', u'CLSD', 4964, u'CREATE TABLE "CLSD" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'HEB', u'HEB', 4973, u'CREATE TABLE "HEB" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'INNL', u'INNL', 5059, u'CREATE TABLE "INNL" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'CLSN', u'CLSN', 5076, u'CREATE TABLE "CLSN" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'TXMD', u'TXMD', 5162, u'CREATE TABLE "TXMD" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'CHRS', u'CHRS', 5213, u'CREATE TABLE "CHRS" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'ALIM', u'ALIM', 5230, u'CREATE TABLE "ALIM" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'GNBT', u'GNBT', 5268, u'CREATE TABLE "GNBT" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'PLX', u'PLX', 5355, u'CREATE TABLE "PLX" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'EARS', u'EARS', 5440, u'CREATE TABLE "EARS" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'ENDP', u'ENDP', 5457, u'CREATE TABLE "ENDP" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'AKBA', u'AKBA', 5541, u'CREATE TABLE "AKBA" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'MYOK', u'MYOK', 5561, u'CREATE TABLE "MYOK" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'NAVB', u'NAVB', 5573, u'CREATE TABLE "NAVB" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'OCRX', u'OCRX', 5660, u'CREATE TABLE "OCRX" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'INSV', u'INSV', 5693, u'CREATE TABLE "INSV" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'INSY', u'INSY', 5710, u'CREATE TABLE "INSY" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'EPZM', u'EPZM', 5793, u'CREATE TABLE "EPZM" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'PTCT', u'PTCT', 5817, u'CREATE TABLE "PTCT" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'CYCC', u'CYCC', 5839, u'CREATE TABLE "CYCC" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'FLKS', u'FLKS', 5906, u'CREATE TABLE "FLKS" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'BLPH', u'BLPH', 5921, u'CREATE TABLE "BLPH" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'ATNM', u'ATNM', 5936, u'CREATE TABLE "ATNM" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'MRNS', u'MRNS', 5967, u'CREATE TABLE "MRNS" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'HSGX', u'HSGX', 5984, u'CREATE TABLE "HSGX" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'PGNX', u'PGNX', 6000, u'CREATE TABLE "PGNX" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'TENX', u'TENX', 6086, u'CREATE TABLE "TENX" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'MDCO', u'MDCO', 6173, u'CREATE TABLE "MDCO" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'AVNR', u'AVNR', 6257, u'CREATE TABLE "AVNR" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'IMRN', u'IMRN', 6331, u'CREATE TABLE "IMRN" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'CELG', u'CELG', 6335, u'CREATE TABLE "CELG" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'ATNX', u'ATNX', 6421, u'CREATE TABLE "ATNX" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'AKRX', u'AKRX', 6425, u'CREATE TABLE "AKRX" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'RXII', u'RXII', 6499, u'CREATE TABLE "RXII" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'VTGN', u'VTGN', 6527, u'CREATE TABLE "VTGN" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'PCYC', u'PCYC', 6536, u'CREATE TABLE "PCYC" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'APRI', u'APRI', 6611, u'CREATE TABLE "APRI" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'AERI', u'AERI', 6697, u'CREATE TABLE "AERI" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'NEOS', u'NEOS', 6718, u'CREATE TABLE "NEOS" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'RDHL', u'RDHL', 6732, u'CREATE TABLE "RDHL" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'CYTK', u'CYTK', 6757, u'CREATE TABLE "CYTK" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'MESO', u'MESO', 6823, u'CREATE TABLE "MESO" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'OCUL', u'OCUL', 6836, u'CREATE TABLE "OCUL" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'XNPT', u'XNPT', 6854, u'CREATE TABLE "XNPT" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'ICPT', u'ICPT', 6909, u'CREATE TABLE "ICPT" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'DMTX', u'DMTX', 6934, u'CREATE TABLE "DMTX" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'ADRO', u'ADRO', 6946, u'CREATE TABLE "ADRO" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'ACRS', u'ACRS', 6960, u'CREATE TABLE "ACRS" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'CERC', u'CERC', 6972, u'CREATE TABLE "CERC" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'ACRX', u'ACRX', 6984, u'CREATE TABLE "ACRX" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'SRNE', u'SRNE', 7017, u'CREATE TABLE "SRNE" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'SCMP', u'SCMP', 7068, u'CREATE TABLE "SCMP" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'REPH', u'REPH', 7119, u'CREATE TABLE "REPH" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'MAPP', u'MAPP', 7139, u'CREATE TABLE "MAPP" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'DRTX', u'DRTX', 7167, u'CREATE TABLE "DRTX" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'INCY', u'INCY', 7181, u'CREATE TABLE "INCY" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'ARDX', u'ARDX', 7268, u'CREATE TABLE "ARDX" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'SNGX', u'SNGX', 7286, u'CREATE TABLE "SNGX" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'POZN', u'POZN', 7372, u'CREATE TABLE "POZN" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'SGYP', u'SGYP', 7374, u'CREATE TABLE "SGYP" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'PSDV', u'PSDV', 7418, u'CREATE TABLE "PSDV" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'KALA', u'KALA', 7480, u'CREATE TABLE "KALA" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'ANIK', u'ANIK', 7482, u'CREATE TABLE "ANIK" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'NBRV', u'NBRV', 7568, u'CREATE TABLE "NBRV" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'ZFGN', u'ZFGN', 7580, u'CREATE TABLE "ZFGN" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'DNDN', u'DNDN', 7598, u'CREATE TABLE "DNDN" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'AGTC', u'AGTC', 7669, u'CREATE TABLE "AGTC" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'MTNB', u'MTNB', 7688, u'CREATE TABLE "MTNB" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'MRSN', u'MRSN', 7705, u'CREATE TABLE "MRSN" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'ZSPH', u'ZSPH', 7707, u'CREATE TABLE "ZSPH" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'GSK', u'GSK', 7717, u'CREATE TABLE "GSK" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'CLVS', u'CLVS', 7803, u'CREATE TABLE "CLVS" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'ADLR', u'ADLR', 7834, u'CREATE TABLE "ADLR" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'DARE', u'DARE', 7889, u'CREATE TABLE "DARE" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'RARE', u'RARE', 7908, u'CREATE TABLE "RARE" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'KERX', u'KERX', 7928, u'CREATE TABLE "KERX" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'XENT', u'XENT', 8012, u'CREATE TABLE "XENT" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'GERN', u'GERN', 8030, u'CREATE TABLE "GERN" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'CHMA', u'CHMA', 8116, u'CREATE TABLE "CHMA" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'ASTX', u'ASTX', 8129, u'CREATE TABLE "ASTX" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'AVIR', u'AVIR', 8196, u'CREATE TABLE "AVIR" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'MYL', u'MYL', 8207, u'CREATE TABLE "MYL" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'RXDX', u'RXDX', 8293, u'CREATE TABLE "RXDX" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'MBIO', u'MBIO', 8313, u'CREATE TABLE "MBIO" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'PCRX', u'PCRX', 8315, u'CREATE TABLE "PCRX" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'NVAX', u'NVAX', 8349, u'CREATE TABLE "NVAX" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'SNNA', u'SNNA', 8435, u'CREATE TABLE "SNNA" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'BOLD', u'BOLD', 8437, u'CREATE TABLE "BOLD" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'RVNC', u'RVNC', 8447, u'CREATE TABLE "RVNC" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'MRK', u'MRK', 8467, u'CREATE TABLE "MRK" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'KPTI', u'KPTI', 8554, u'CREATE TABLE "KPTI" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'ARLZ', u'ARLZ', 8575, u'CREATE TABLE "ARLZ" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'PBYI', u'PBYI', 8585, u'CREATE TABLE "PBYI" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'AMRN', u'AMRN', 8613, u'CREATE TABLE "AMRN" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'SRPT', u'SRPT', 8699, u'CREATE TABLE "SRPT" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'ITMN', u'ITMN', 8785, u'CREATE TABLE "ITMN" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'ARQL', u'ARQL', 8856, u'CREATE TABLE "ARQL" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'PDLI', u'PDLI', 8942, u'CREATE TABLE "PDLI" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'VBLT', u'VBLT', 9028, u'CREATE TABLE "VBLT" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'SUPN', u'SUPN', 9045, u'CREATE TABLE "SUPN" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'ALRN', u'ALRN', 9073, u'CREATE TABLE "ALRN" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'ARGX', u'ARGX', 9075, u'CREATE TABLE "ARGX" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'ARGS', u'ARGS', 9079, u'CREATE TABLE "ARGS" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'HZNP', u'HZNP', 9099, u'CREATE TABLE "HZNP" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'REGN', u'REGN', 9131, u'CREATE TABLE "REGN" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'SOMX', u'SOMX', 9218, u'CREATE TABLE "SOMX" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'COLL', u'COLL', 9254, u'CREATE TABLE "COLL" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'BMRN', u'BMRN', 9268, u'CREATE TABLE "BMRN" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'HTBX', u'HTBX', 9354, u'CREATE TABLE "HTBX" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'GTXI', u'GTXI', 9376, u'CREATE TABLE "GTXI" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'CTIC', u'CTIC', 9443, u'CREATE TABLE "CTIC" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'PULM', u'PULM', 9530, u'CREATE TABLE "PULM" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'LLY', u'LLY', 9550, u'CREATE TABLE "LLY" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'PTI', u'PTI', 9636, u'CREATE TABLE "PTI" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'IDRA', u'IDRA', 9646, u'CREATE TABLE "IDRA" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'VTVT', u'VTVT', 9732, u'CREATE TABLE "VTVT" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'SGMO', u'SGMO', 9745, u'CREATE TABLE "SGMO" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'OSI', u'OSI', 9830, u'CREATE TABLE "OSI" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'TEVA', u'TEVA', 9888, u'CREATE TABLE "TEVA" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'ALNY', u'ALNY', 9974, u'CREATE TABLE "ALNY" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'BMY', u'BMY', 10040, u'CREATE TABLE "BMY" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'RPRX', u'RPRX', 10128, u'CREATE TABLE "RPRX" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'INVA', u'INVA', 10214, u'CREATE TABLE "INVA" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'ANAC', u'ANAC', 10293, u'CREATE TABLE "ANAC" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'EVOK', u'EVOK', 10297, u'CREATE TABLE "EVOK" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'AUXL', u'AUXL', 10318, u'CREATE TABLE "AUXL" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'JAZZ', u'JAZZ', 10370, u'CREATE TABLE "JAZZ" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'UTHR', u'UTHR', 10421, u'CREATE TABLE "UTHR" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'EYEG', u'EYEG', 10507, u'CREATE TABLE "EYEG" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'AEZS', u'AEZS', 10520, u'CREATE TABLE "AEZS" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'TCON', u'TCON', 10604, u'CREATE TABLE "TCON" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'AQXP', u'AQXP', 10619, u'CREATE TABLE "AQXP" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'XNCR', u'XNCR', 10639, u'CREATE TABLE "XNCR" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'FBIO', u'FBIO', 10660, u'CREATE TABLE "FBIO" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'AMPH', u'AMPH', 10690, u'CREATE TABLE "AMPH" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'NPSP', u'NPSP', 10708, u'CREATE TABLE "NPSP" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'CLDA', u'CLDA', 10782, u'CREATE TABLE "CLDA" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'FENC', u'FENC', 10837, u'CREATE TABLE "FENC" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'VVUS', u'VVUS', 10855, u'CREATE TABLE "VVUS" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'BTX', u'BTX', 10941, u'CREATE TABLE "BTX" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'LXRX', u'LXRX', 11027, u'CREATE TABLE "LXRX" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'NVCR', u'NVCR', 11112, u'CREATE TABLE "NVCR" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'AIMT', u'AIMT', 11124, u'CREATE TABLE "AIMT" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'OGEN', u'OGEN', 11137, u'CREATE TABLE "OGEN" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'GTHX', u'GTHX', 11203, u'CREATE TABLE "GTHX" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'ANTH', u'ANTH', 11207, u'CREATE TABLE "ANTH" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'ACAD', u'ACAD', 11246, u'CREATE TABLE "ACAD" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'AGIO', u'AGIO', 11312, u'CREATE TABLE "AGIO" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'SBBP', u'SBBP', 11334, u'CREATE TABLE "SBBP" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'RGEN', u'RGEN', 11346, u'CREATE TABLE "RGEN" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'TOCA', u'TOCA', 11432, u'CREATE TABLE "TOCA" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'IMDZ', u'IMDZ', 11436, u'CREATE TABLE "IMDZ" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'SPHS', u'SPHS', 11454, u'CREATE TABLE "SPHS" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'ONXX', u'ONXX', 11491, u'CREATE TABLE "ONXX" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'XLRN', u'XLRN', 11558, u'CREATE TABLE "XLRN" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'CLRB', u'CLRB', 11580, u'CREATE TABLE "CLRB" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'BMTI', u'BMTI', 11640, u'CREATE TABLE "BMTI" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'ADHD', u'ADHD', 11675, u'CREATE TABLE "ADHD" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'NEW', u'NEW', 11699, u'CREATE TABLE "NEW" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'PDL', u'PDL', 11771, u'CREATE TABLE "PDL" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'MBRX', u'MBRX', 11806, u'CREATE TABLE "MBRX" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'GEMP', u'GEMP', 11815, u'CREATE TABLE "GEMP" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'ISIS', u'ISIS', 11823, u'CREATE TABLE "ISIS" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'AVEO', u'AVEO', 11901, u'CREATE TABLE "AVEO" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'AST', u'AST', 11940, u'CREATE TABLE "AST" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'ONCS', u'ONCS', 11958, u'CREATE TABLE "ONCS" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'LGND', u'LGND', 11991, u'CREATE TABLE "LGND" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'GEVA', u'GEVA', 12077, u'CREATE TABLE "GEVA" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'MDVN', u'MDVN', 12098, u'CREATE TABLE "MDVN" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'MCRB', u'MCRB', 12103, u'CREATE TABLE "MCRB" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'ONCE', u'ONCE', 12116, u'CREATE TABLE "ONCE" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'IONS', u'IONS', 12132, u'CREATE TABLE "IONS" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'MDGL', u'MDGL', 12218, u'CREATE TABLE "MDGL" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'CDTX', u'CDTX', 12271, u'CREATE TABLE "CDTX" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'GILD', u'GILD', 12285, u'CREATE TABLE "GILD" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'FGEN', u'FGEN', 12371, u'CREATE TABLE "FGEN" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'SHPG', u'SHPG', 12387, u'CREATE TABLE "SHPG" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'RGNX', u'RGNX', 12473, u'CREATE TABLE "RGNX" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'VTL', u'VTL', 12486, u'CREATE TABLE "VTL" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'CORT', u'CORT', 12504, u'CREATE TABLE "CORT" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'AMLN', u'AMLN', 12570, u'CREATE TABLE "AMLN" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'PRTA', u'PRTA', 12632, u'CREATE TABLE "PRTA" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'OMER', u'OMER', 12657, u'CREATE TABLE "OMER" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'ELTP', u'ELTP', 12697, u'CREATE TABLE "ELTP" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'FRX', u'FRX', 12783, u'CREATE TABLE "FRX" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'PRTO', u'PRTO', 12854, u'CREATE TABLE "PRTO" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'ALKS', u'ALKS', 12871, u'CREATE TABLE "ALKS" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'BLUE', u'BLUE', 12957, u'CREATE TABLE "BLUE" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'RIGL', u'RIGL', 12980, u'CREATE TABLE "RIGL" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'CHTP', u'CHTP', 13062, u'CREATE TABLE "CHTP" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'MNKD', u'MNKD', 13105, u'CREATE TABLE "MNKD" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'EGLT', u'EGLT', 13171, u'CREATE TABLE "EGLT" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'PTIE', u'PTIE', 13191, u'CREATE TABLE "PTIE" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'CLBS', u'CLBS', 13275, u'CREATE TABLE "CLBS" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'VKTX', u'VKTX', 13361, u'CREATE TABLE "VKTX" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'ARNA', u'ARNA', 13375, u'CREATE TABLE "ARNA" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'MDWD', u'MDWD', 13459, u'CREATE TABLE "MDWD" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'NLNK', u'NLNK', 13479, u'CREATE TABLE "NLNK" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'VRNA', u'VRNA', 13509, u'CREATE TABLE "VRNA" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'GALT', u'GALT', 13513, u'CREATE TABLE "GALT" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'AGRX', u'AGRX', 13587, u'CREATE TABLE "AGRX" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'SLXP', u'SLXP', 13605, u'CREATE TABLE "SLXP" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'GNMX', u'GNMX', 13675, u'CREATE TABLE "GNMX" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'ARDM', u'ARDM', 13708, u'CREATE TABLE "ARDM" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'AXON', u'AXON', 13793, u'CREATE TABLE "AXON" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'DERM', u'DERM', 13808, u'CREATE TABLE "DERM" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'ABIO', u'ABIO', 13825, u'CREATE TABLE "ABIO" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'STML', u'STML', 13910, u'CREATE TABLE "STML" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'PATH', u'PATH', 13935, u'CREATE TABLE "PATH" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'KMDA', u'KMDA', 13955, u'CREATE TABLE "KMDA" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'OHRP', u'OHRP', 13978, u'CREATE TABLE "OHRP" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'PTLA', u'PTLA', 14042, u'CREATE TABLE "PTLA" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'EIGR', u'EIGR', 14066, u'CREATE TABLE "EIGR" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'BIIB', u'BIIB', 14076, u'CREATE TABLE "BIIB" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'KDMN', u'KDMN', 14162, u'CREATE TABLE "KDMN" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'TTPH', u'TTPH', 14171, u'CREATE TABLE "TTPH" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'SCYX', u'SCYX', 14195, u'CREATE TABLE "SCYX" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'CYTR', u'CYTR', 14213, u'CREATE TABLE "CYTR" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'ARRY', u'ARRY', 14299, u'CREATE TABLE "ARRY" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'AKAO', u'AKAO', 14381, u'CREATE TABLE "AKAO" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'HOLX', u'HOLX', 14401, u'CREATE TABLE "HOLX" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'OBSV', u'OBSV', 14488, u'CREATE TABLE "OBSV" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'RGLS', u'RGLS', 14493, u'CREATE TABLE "RGLS" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'EBS', u'EBS', 14519, u'CREATE TABLE "EBS" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'CORI', u'CORI', 14573, u'CREATE TABLE "CORI" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'ABBV', u'ABBV', 14592, u'CREATE TABLE "ABBV" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'ALXN', u'ALXN', 14617, u'CREATE TABLE "ALXN" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'TSRO', u'TSRO', 14703, u'CREATE TABLE "TSRO" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'CALA', u'CALA', 14731, u'CREATE TABLE "CALA" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'ALXA', u'ALXA', 14748, u'CREATE TABLE "ALXA" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'MACK', u'MACK', 14752, u'CREATE TABLE "MACK" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'TRVN', u'TRVN', 14781, u'CREATE TABLE "TRVN" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'CFRX', u'CFRX', 14801, u'CREATE TABLE "CFRX" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'ZGNX', u'ZGNX', 14818, u'CREATE TABLE "ZGNX" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'PFE', u'PFE', 14853, u'CREATE TABLE "PFE" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'CLDX', u'CLDX', 14940, u'CREATE TABLE "CLDX" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'IPCI', u'IPCI', 15026, u'CREATE TABLE "IPCI" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'FOMX', u'FOMX', 15067, u'CREATE TABLE "FOMX" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'VICL', u'VICL', 15084, u'CREATE TABLE "VICL" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'BDSI', u'BDSI', 15170, u'CREATE TABLE "BDSI" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'NKTR', u'NKTR', 15244, u'CREATE TABLE "NKTR" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'TTNP', u'TTNP', 15330, u'CREATE TABLE "TTNP" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'KYTH', u'KYTH', 15416, u'CREATE TABLE "KYTH" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)'),
#  (u'table', u'MRTX', u'MRTX', 15433, u'CREATE TABLE "MRTX" (\n\t"index" TEXT, \n\tvolume FLOAT, \n\tclose FLOAT, \n\thigh FLOAT, \n\topen FLOAT, \n\tlow FLOAT\n)')]

# %%
# %%sql
# select *
# FROM amgn
# LIMIT 200
# Out:
# Done.
# [(u'2000-01-03', 22914900.0, 60.06, 60.06, 60.06, 60.06),
#  (u'2000-01-04', 15052600.0, 58.13, 64.13, 62.0, 57.69),
#  (u'2000-01-05', 15071400.0, 59.94, 60.25, 59.19, 58.25),
#  (u'2000-01-06', 11118400.0, 61.13, 61.94, 60.75, 60.25),
#  (u'2000-01-07', 15953900.0, 68.0, 68.5, 62.75, 62.63),
#  (u'2000-01-10', 10555300.0, 72.13, 72.69, 69.5, 69.5),
#  (u'2000-01-11', 14103100.0, 66.44, 72.38, 72.06, 64.13),
#  (u'2000-01-12', 11576800.0, 63.56, 67.75, 67.63, 62.56),
#  (u'2000-01-13', 10552600.0, 66.81, 67.75, 64.75, 63.81),
#  (u'2000-01-14', 8971200.0, 68.31, 70.0, 68.88, 67.38),
#  (u'2000-01-18', 8658100.0, 69.06, 70.13, 70.0, 68.25),
#  (u'2000-01-19', 12070900.0, 72.0, 72.94, 70.0, 69.88),
#  (u'2000-01-20', 9460900.0, 71.81, 74.5, 74.38, 69.63),
#  (u'2000-01-21', 8154300.0, 74.69, 75.0, 73.38, 72.0),
#  (u'2000-01-24', 9853500.0, 69.25, 76.5, 75.88, 69.13),
#  (u'2000-01-25', 11251900.0, 69.38, 70.81, 70.75, 66.0),
#  (u'2000-01-26', 16000800.0, 64.13, 68.88, 67.88, 64.06),
#  (u'2000-01-27', 14797000.0, 61.38, 65.06, 65.0, 59.13),
#  (u'2000-01-28', 10899900.0, 59.69, 61.44, 61.44, 59.38),
#  (u'2000-01-31', 12619500.0, 63.69, 63.88, 61.0, 59.88),
#  (u'2000-02-01', 9902700.0, 65.31, 66.0, 64.75, 62.75),
#  (u'2000-02-02', 9976900.0, 63.75, 65.13, 65.13, 61.88),
#  (u'2000-02-03', 7613000.0, 64.0, 65.0, 64.75, 62.38),
#  (u'2000-02-04', 8069600.0, 64.63, 66.5, 64.75, 64.13),
#  (u'2000-02-07', 9190200.0, 69.19, 69.56, 66.5, 65.13),
#  (u'2000-02-08', 11108300.0, 70.5, 72.19, 70.38, 69.19),
#  (u'2000-02-09', 7774100.0, 66.81, 71.5, 71.25, 66.63),
#  (u'2000-02-10', 8880100.0, 65.19, 67.5, 67.38, 64.5),
#  (u'2000-02-11', 8105000.0, 62.63, 66.31, 65.31, 61.94),
#  (u'2000-02-14', 8794600.0, 65.06, 65.88, 63.56, 62.38),
#  (u'2000-02-15', 8358400.0, 65.06, 65.75, 65.25, 64.19),
#  (u'2000-02-16', 11654800.0, 69.88, 70.0, 65.13, 64.75),
#  (u'2000-02-17', 14842800.0, 72.75, 74.0, 70.19, 69.94),
#  (u'2000-02-18', 14959700.0, 71.31, 75.0, 74.5, 69.94),
#  (u'2000-02-22', 8657100.0, 67.5, 71.94, 71.69, 66.38),
#  (u'2000-02-23', 9098600.0, 71.44, 72.13, 68.69, 67.13),
#  (u'2000-02-24', 9630100.0, 72.56, 73.19, 72.13, 68.45),
#  (u'2000-02-25', 8556500.0, 73.56, 74.0, 73.0, 70.13),
#  (u'2000-02-28', 13264800.0, 68.44, 72.88, 72.88, 66.5),
#  (u'2000-02-29', 8593500.0, 68.19, 70.5, 70.25, 67.13),
#  (u'2000-03-01', 10212300.0, 65.06, 67.25, 67.0, 64.81),
#  (u'2000-03-02', 12075000.0, 65.31, 67.88, 65.31, 63.0),
#  (u'2000-03-03', 10481000.0, 66.31, 67.88, 66.88, 65.0),
#  (u'2000-03-06', 12645900.0, 64.56, 66.88, 66.88, 63.31),
#  (u'2000-03-07', 12739800.0, 61.0, 65.5, 65.44, 60.5),
#  (u'2000-03-08', 15595000.0, 61.38, 63.38, 63.0, 60.69),
#  (u'2000-03-09', 10935000.0, 59.0, 61.69, 61.56, 58.88),
#  (u'2000-03-10', 16043800.0, 59.56, 63.38, 60.0, 58.75),
#  (u'2000-03-13', 10081100.0, 58.0, 60.25, 58.19, 58.0),
#  (u'2000-03-14', 27589100.0, 52.25, 60.0, 59.88, 51.06),
#  (u'2000-03-15', 33529500.0, 58.5, 59.38, 57.19, 56.0),
#  (u'2000-03-16', 18216200.0, 64.75, 65.5, 62.5, 61.13),
#  (u'2000-03-17', 12260600.0, 63.13, 65.19, 64.25, 62.19),
#  (u'2000-03-20', 20278200.0, 58.0, 62.38, 62.25, 56.94),
#  (u'2000-03-21', 16598600.0, 61.13, 61.5, 58.13, 55.13),
#  (u'2000-03-22', 11226000.0, 61.75, 63.13, 61.69, 60.0),
#  (u'2000-03-23', 20064100.0, 57.69, 58.5, 58.0, 56.81),
#  (u'2000-03-24', 21633800.0, 57.69, 57.69, 57.69, 57.69),
#  (u'2000-03-27', 15924900.0, 60.38, 61.0, 55.13, 55.13),
#  (u'2000-03-28', 18037600.0, 62.81, 65.75, 61.25, 60.41),
#  (u'2000-03-29', 10524700.0, 62.25, 65.88, 64.94, 61.69),
#  (u'2000-03-30', 9182700.0, 60.25, 64.31, 61.56, 59.0),
#  (u'2000-03-31', 7864600.0, 61.38, 63.0, 61.63, 59.63),
#  (u'2000-04-03', 6449800.0, 59.38, 61.94, 61.0, 58.13),
#  (u'2000-04-04', 14755200.0, 56.44, 60.13, 60.13, 53.81),
#  (u'2000-04-05', 10977800.0, 59.63, 62.25, 56.31, 56.0),
#  (u'2000-04-06', 10843500.0, 62.31, 64.38, 61.89, 61.5),
#  (u'2000-04-07', 8580600.0, 60.94, 64.38, 63.44, 60.25),
#  (u'2000-04-10', 9390100.0, 58.88, 63.75, 62.0, 58.75),
#  (u'2000-04-11', 7586200.0, 59.13, 60.38, 58.0, 57.0),
#  (u'2000-04-12', 7345800.0, 58.39, 61.5, 60.13, 58.19),
#  (u'2000-04-13', 8131900.0, 57.81, 61.38, 59.56, 56.5),
#  (u'2000-04-14', 12667000.0, 52.75, 58.0, 56.69, 52.13),
#  (u'2000-04-17', 12355900.0, 53.38, 54.25, 52.38, 50.0),
#  (u'2000-04-18', 9480500.0, 58.38, 58.5, 54.77, 54.13),
#  (u'2000-04-19', 9010200.0, 56.0, 59.94, 58.44, 55.25),
#  (u'2000-04-20', 7848300.0, 54.0, 57.25, 56.75, 53.19),
#  (u'2000-04-24', 11779300.0, 51.31, 53.8, 53.31, 50.0),
#  (u'2000-04-25', 11171500.0, 54.31, 54.56, 53.19, 51.25),
#  (u'2000-04-26', 31026200.0, 57.25, 61.3, 52.88, 52.5),
#  (u'2000-04-27', 12936000.0, 54.13, 55.63, 55.55, 52.63),
#  (u'2000-04-28', 12969900.0, 56.0, 56.38, 55.25, 53.0),
#  (u'2000-05-01', 7822900.0, 55.88, 57.94, 57.0, 55.13),
#  (u'2000-05-02', 8039500.0, 56.13, 57.75, 55.88, 55.39),
#  (u'2000-05-03', 6569700.0, 53.75, 56.06, 56.0, 52.88),
#  (u'2000-05-04', 7953500.0, 56.56, 57.75, 54.5, 54.38),
#  (u'2000-05-05', 7025100.0, 59.56, 59.81, 55.88, 55.63),
#  (u'2000-05-08', 9295600.0, 61.88, 62.69, 59.0, 57.88),
#  (u'2000-05-09', 6544300.0, 59.94, 61.94, 61.94, 58.75),
#  (u'2000-05-10', 5981400.0, 59.81, 61.0, 59.44, 58.25),
#  (u'2000-05-11', 5714400.0, 61.63, 62.0, 60.31, 59.31),
#  (u'2000-05-12', 4738900.0, 62.38, 62.44, 61.88, 60.88),
#  (u'2000-05-15', 6272200.0, 64.19, 64.75, 62.13, 61.19),
#  (u'2000-05-16', 8408500.0, 64.69, 65.19, 64.88, 63.31),
#  (u'2000-05-17', 4834700.0, 62.92, 64.38, 63.63, 62.81),
#  (u'2000-05-18', 4920200.0, 61.19, 63.75, 63.38, 61.0),
#  (u'2000-05-19', 5703300.0, 59.88, 60.88, 59.88, 59.63),
#  (u'2000-05-22', 10503300.0, 57.19, 60.25, 60.19, 56.25),
#  (u'2000-05-23', 7174300.0, 55.56, 60.0, 57.19, 55.5),
#  (u'2000-05-24', 8013100.0, 59.63, 59.69, 56.69, 55.94),
#  (u'2000-05-25', 6319500.0, 57.94, 62.13, 60.13, 57.75),
#  (u'2000-05-26', 3271000.0, 59.0, 59.5, 58.13, 57.0),
#  (u'2000-05-30', 5253800.0, 63.38, 63.56, 60.31, 60.31),
#  (u'2000-05-31', 7618000.0, 63.63, 64.94, 63.13, 62.5),
#  (u'2000-06-01', 6144000.0, 64.81, 65.25, 63.94, 62.13),
#  (u'2000-06-02', 10113800.0, 67.0, 68.5, 66.0, 66.0),
#  (u'2000-06-05', 6382900.0, 67.06, 68.81, 66.56, 66.25),
#  (u'2000-06-06', 6327000.0, 67.5, 69.5, 67.31, 66.13),
#  (u'2000-06-07', 3942800.0, 68.0, 68.5, 67.94, 66.44),
#  (u'2000-06-08', 5272200.0, 65.69, 68.19, 68.13, 65.25),
#  (u'2000-06-09', 10110500.0, 62.63, 68.5, 66.0, 61.0),
#  (u'2000-06-12', 9648700.0, 61.0, 63.94, 63.25, 60.0),
#  (u'2000-06-13', 6875300.0, 65.69, 65.88, 60.88, 60.88),
#  (u'2000-06-14', 4743400.0, 64.31, 66.25, 66.25, 63.63),
#  (u'2000-06-15', 5766900.0, 66.44, 66.75, 65.17, 64.38),
#  (u'2000-06-16', 8687700.0, 68.0, 69.13, 67.5, 65.5),
#  (u'2000-06-19', 6660500.0, 70.38, 70.44, 67.69, 67.06),
#  (u'2000-06-20', 8561200.0, 70.0, 70.44, 70.19, 69.56),
#  (u'2000-06-21', 5478500.0, 70.31, 70.88, 69.44, 69.13),
#  (u'2000-06-22', 5983000.0, 66.69, 70.0, 69.5, 66.25),
#  (u'2000-06-23', 3792200.0, 66.63, 68.63, 66.63, 65.88),
#  (u'2000-06-26', 5719000.0, 69.94, 70.13, 67.5, 66.75),
#  (u'2000-06-27', 5663500.0, 67.38, 70.19, 69.88, 66.5),
#  (u'2000-06-28', 4754000.0, 69.13, 69.94, 67.31, 67.13),
#  (u'2000-06-29', 4604000.0, 68.25, 69.75, 68.44, 67.56),
#  (u'2000-06-30', 6730700.0, 70.25, 70.5, 67.75, 66.56),
#  (u'2000-07-03', 3186800.0, 68.5, 69.75, 69.69, 68.31),
#  (u'2000-07-05', 13114900.0, 73.81, 74.25, 69.38, 68.88),
#  (u'2000-07-06', 9974600.0, 73.25, 73.63, 72.75, 70.0),
#  (u'2000-07-07', 9534800.0, 73.94, 76.0, 73.75, 73.06),
#  (u'2000-07-10', 7577600.0, 73.13, 75.94, 74.5, 72.63),
#  (u'2000-07-11', 6149300.0, 73.19, 74.81, 72.5, 72.44),
#  (u'2000-07-12', 5595100.0, 73.38, 74.81, 74.75, 71.44),
#  (u'2000-07-13', 8188600.0, 69.44, 73.81, 73.06, 68.69),
#  (u'2000-07-14', 6284100.0, 70.75, 71.88, 69.94, 69.5),
#  (u'2000-07-17', 6009900.0, 72.38, 73.94, 71.31, 71.19),
#  (u'2000-07-18', 6063000.0, 74.86, 76.0, 71.94, 71.75),
#  (u'2000-07-19', 6572200.0, 73.44, 74.88, 74.19, 73.06),
#  (u'2000-07-20', 5608100.0, 74.06, 74.75, 73.88, 73.63),
#  (u'2000-07-21', 15289500.0, 78.0, 79.98, 72.88, 72.75),
#  (u'2000-07-24', 8720300.0, 74.75, 80.44, 79.19, 74.5),
#  (u'2000-07-25', 5172100.0, 73.63, 76.0, 75.56, 72.25),
#  (u'2000-07-26', 9597200.0, 69.38, 75.88, 74.44, 69.13),
#  (u'2000-07-27', 13737000.0, 68.5, 71.5, 69.13, 68.25),
#  (u'2000-07-28', 8268400.0, 66.38, 69.63, 69.13, 65.13),
#  (u'2000-07-31', 6788200.0, 64.94, 67.5, 66.75, 64.75),
#  (u'2000-08-01', 9298200.0, 69.0, 69.25, 65.31, 65.0),
#  (u'2000-08-02', 7762200.0, 70.31, 71.38, 69.0, 68.06),
#  (u'2000-08-03', 5829000.0, 70.19, 71.63, 68.88, 68.88),
#  (u'2000-08-04', 5847600.0, 69.13, 71.38, 70.56, 67.56),
#  (u'2000-08-07', 7908000.0, 72.13, 72.25, 69.19, 67.81),
#  (u'2000-08-08', 6420100.0, 69.5, 72.0, 71.81, 69.34),
#  (u'2000-08-09', 5265800.0, 68.94, 70.5, 70.19, 68.88),
#  (u'2000-08-10', 4668700.0, 67.94, 69.19, 69.0, 67.25),
#  (u'2000-08-11', 4336700.0, 69.69, 69.94, 68.63, 66.75),
#  (u'2000-08-14', 3320500.0, 69.44, 69.88, 69.63, 68.06),
#  (u'2000-08-15', 5147100.0, 67.75, 69.5, 69.38, 67.13),
#  (u'2000-08-16', 4312000.0, 68.13, 69.63, 69.0, 67.94),
#  (u'2000-08-17', 5090600.0, 67.81, 69.44, 68.75, 67.63),
#  (u'2000-08-18', 5871600.0, 65.88, 67.94, 67.38, 65.81),
#  (u'2000-08-21', 4673300.0, 67.25, 68.94, 66.88, 66.38),
#  (u'2000-08-22', 5550200.0, 69.06, 69.63, 67.75, 67.69),
#  (u'2000-08-23', 7099700.0, 70.56, 71.5, 71.0, 69.13),
#  (u'2000-08-24', 6144800.0, 72.63, 73.25, 70.75, 70.75),
#  (u'2000-08-25', 6089400.0, 74.63, 75.63, 73.06, 72.94),
#  (u'2000-08-28', 4627700.0, 73.75, 76.0, 74.88, 72.88),
#  (u'2000-08-29', 5194100.0, 72.13, 74.63, 74.5, 72.0),
#  (u'2000-08-30', 4622300.0, 73.06, 73.75, 72.31, 71.75),
#  (u'2000-08-31', 7785200.0, 75.81, 76.63, 73.25, 72.69),
#  (u'2000-09-01', 4917600.0, 76.44, 76.63, 76.56, 74.19),
#  (u'2000-09-05', 7469600.0, 72.5, 76.0, 76.0, 71.88),
#  (u'2000-09-06', 9203300.0, 68.06, 73.0, 72.5, 68.0),
#  (u'2000-09-07', 7854100.0, 72.0, 73.13, 69.69, 69.63),
#  (u'2000-09-08', 8089800.0, 74.94, 76.31, 72.81, 71.19),
#  (u'2000-09-11', 6646200.0, 72.25, 74.88, 74.13, 72.0),
#  (u'2000-09-12', 4767700.0, 72.75, 74.13, 72.0, 71.38),
#  (u'2000-09-13', 5692500.0, 71.94, 72.5, 72.38, 71.25),
#  (u'2000-09-14', 21630800.0, 67.44, 71.88, 71.88, 65.19),
#  (u'2000-09-15', 12453900.0, 67.63, 69.63, 68.75, 66.63),
#  (u'2000-09-18', 5783700.0, 65.19, 68.56, 68.38, 64.94),
#  (u'2000-09-19', 6249100.0, 65.69, 67.81, 66.0, 64.13),
#  (u'2000-09-20', 5918400.0, 69.13, 69.38, 66.75, 66.0),
#  (u'2000-09-21', 4976100.0, 68.44, 69.5, 68.5, 67.31),
#  (u'2000-09-22', 7185400.0, 72.06, 72.13, 68.25, 68.25),
#  (u'2000-09-25', 6932500.0, 69.69, 73.88, 72.06, 69.13),
#  (u'2000-09-26', 5887200.0, 71.56, 72.0, 69.94, 68.94),
#  (u'2000-09-27', 5427600.0, 71.38, 71.88, 70.5, 69.69),
#  (u'2000-09-28', 7519100.0, 70.25, 71.0, 70.41, 68.5),
#  (u'2000-09-29', 5732900.0, 69.83, 71.38, 70.63, 69.13),
#  (u'2000-10-02', 8224700.0, 65.75, 70.44, 70.31, 65.13),
#  (u'2000-10-03', 5578400.0, 66.75, 69.0, 67.97, 66.5),
#  (u'2000-10-04', 8179500.0, 64.44, 67.31, 67.25, 63.5),
#  (u'2000-10-05', 4932400.0, 66.63, 67.5, 64.0, 64.0),
#  (u'2000-10-06', 6830400.0, 63.06, 67.0, 66.63, 61.5),
#  (u'2000-10-09', 3295700.0, 63.19, 64.69, 63.38, 62.0),
#  (u'2000-10-10', 7811600.0, 60.69, 63.88, 62.78, 60.63),
#  (u'2000-10-11', 7110600.0, 65.69, 67.56, 59.75, 59.5),
#  (u'2000-10-12', 10082700.0, 61.88, 65.38, 65.38, 59.94),
#  (u'2000-10-13', 4694800.0, 64.88, 65.0, 60.44, 60.38),
#  (u'2000-10-16', 7142600.0, 63.81, 66.13, 65.38, 61.81)]
