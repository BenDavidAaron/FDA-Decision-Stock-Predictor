# %%
import numpy as np
import pandas as pd
import dill
from tsfresh import extract_features
from tsfresh import select_features
from tsfresh.utilities.dataframe_functions import impute
# Out:
# /opt/conda/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
test_df = dill.load(open("test_df.pkl", "r"))
train_df = dill.load(open("train_df.pkl", "r"))

# %%
train_feats = extract_features(train_df, 
                              column_id="event_stamp", column_sort="date_stamp", 
                              column_value="norm_price", n_jobs=0)
# Out:
# Feature Extraction: 100%|██████████| 211/211 [00:00<00:00, 31034.05it/s]

# %%
train_feats
# Out:
# variable  norm_price__abs_energy  norm_price__absolute_sum_of_changes  \
# id
# 0                      34.173004                             1.538663
# 1                     524.313801                             4.845498
# 2                     194.638231                             2.144684
# 3                      41.039416                             0.341473
# 4                      34.720704                             0.392413
# 5                      36.756893                             0.613058
# 6                     100.909814                             2.460290
# 7                      45.410460                             2.762660
# 8                       4.395851                             1.704358
# 9                       9.364516                             1.295229
# 10                     40.953194                             0.537085
# 11                      4.973197                             1.483392
# ...

# %%
y = train_df[['event_stamp', 'outcome']]

# %%
impute(train_feats)
features_filtered = select_features(train_feats, train_df.head['outcome'].astype('bool'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-67304e6d5cab> in <module>()
#       1 impute(train_feats)
# ----> 2 features_filtered = select_features(train_feats, train_df.head(2)['outcome'].astype('bool'))
#
# /opt/conda/lib/python2.7/site-packages/tsfresh/feature_selection/selection.pyc in select_features(X, y, test_for_binary_target_binary_feature, test_for_binary_target_real_feature, test_for_real_target_binary_feature, test_for_real_target_real_feature, fdr_level, hypotheses_independent, n_jobs, chunksize, ml_task)
#     130         raise ValueError("X must contain at least two samples.")
#     131     elif isinstance(y, pd.Series) and not X.index.isin(y.index).all():
# --> 132         raise ValueError("Index of X must be a subset of y's index")
#     133     elif isinstance(y, np.ndarray):
#     134         if not len(y) >= len(X):
#
# ...
